# %%
import os
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from matplotlib.lines import Line2D
import seaborn as sns
sns.set_theme()

from source.constants import PLOTS_PATH

os.makedirs(PLOTS_PATH, exist_ok=True)

# %%
# data taken from analyze_face_detection_calibration.ipynb
ff_ece_means = [0.154, 0.069, 0.091]
ff_ece_stds = [0.019, 0.003, 0.024]
ff_m_ece_means = [0.070, 0.026, 0.046]
ff_m_ece_stds = [0.004, 0.002, 0.006]
ff_labels = ["age", "gender", "race"]

utk_ece_means = [0.181, 0.061, 0.136]
utk_ece_stds = [0.012, 0.002, 0.023]
utk_m_ece_means = [0.122, 0.033, 0.102]
utk_m_ece_stds = [0.004, 0.001, 0.006]
utk_labels = ["age", "gender", "race"]

# data taken from analyze_medical_image_calibration.ipynb
cx_ece_means = [0.012]
cx_ece_stds = [0.003]
cx_m_ece_means = [0.011]
cx_m_ece_stds = [0.001]
cx_labels = ["n.f."]

# %%
c_member = "gray"
c_ens = "C3"

plt.figure(figsize=(6, 3))

min_length = 0
plt.bar([x - 0.2 for x in range(min_length, len(ff_ece_means))], 
        ff_ece_means, yerr=ff_ece_stds, color=c_member, label="Members", capsize=5, width=0.4)
plt.bar([x + 0.2 for x in range(min_length, len(ff_m_ece_means))], 
        ff_m_ece_means, yerr=ff_m_ece_stds, color=c_ens, label="Deep Ensemble", capsize=5, width=0.4)
min_length = len(ff_ece_means)
plt.bar([x - 0.2 for x in range(min_length, min_length + len(utk_ece_means))], 
        utk_ece_means, yerr=utk_ece_stds, color=c_member, capsize=5, width=0.4)
plt.bar([x + 0.2 for x in range(min_length, min_length + len(utk_m_ece_means))],
        utk_m_ece_means, yerr=utk_m_ece_stds, color=c_ens, capsize=5, width=0.4)
min_length += len(utk_ece_means)
plt.bar([x - 0.2 for x in range(min_length, min_length + len(cx_ece_means))], 
        cx_ece_means, yerr=cx_ece_stds, color=c_member, capsize=5, width=0.4)
plt.bar([x + 0.2 for x in range(min_length, min_length + len(cx_m_ece_means))],
        cx_m_ece_means, yerr=cx_m_ece_stds, color=c_ens, capsize=5, width=0.4)
plt.xticks(range(len(ff_ece_means) + len(utk_ece_means) + len(cx_ece_means)),
              ff_labels + utk_labels + cx_labels, rotation=0)
plt.text(1, 0.143, "FF", fontsize="medium", ha="center", bbox=dict(boxstyle='round, pad=0.3', edgecolor='black', facecolor='white', alpha=0.3))
plt.text(4, 0.143, "UTK", fontsize="medium", ha="center", bbox=dict(boxstyle='round, pad=0.3', edgecolor='black', facecolor='white', alpha=0.3))
plt.text(6, 0.143, "CX", fontsize="medium", ha="center", bbox=dict(boxstyle='round, pad=0.3', edgecolor='black', facecolor='white', alpha=0.3))
ymax = plt.gca().get_ylim()[1] * 1.05
plt.vlines(2.5, 0, ymax, color="black", linestyle=":", alpha=0.3)
plt.vlines(5.5, 0, ymax, color="black", linestyle=":", alpha=0.3)
plt.ylim(0, ymax)
plt.xlim(-0.55, 6.55)
plt.ylabel("ECE ($\\leftarrow$)")
plt.xlabel("Target")
plt.legend(fontsize="x-small")
plt.tight_layout()
plt.savefig(os.path.join(PLOTS_PATH, "ece.pdf"))
plt.show()

# %%
# data taken from analyze_face_detection_calibration.ipynb

ff_ece_means_a0 = [0.164, 0.152, 0.093, 0.069, 0.084, 0.090]
ff_ece_stds_a0 = [0.019, 0.018, 0.004, 0.003, 0.022, 0.023]
ff_m_ece_means_a0 = [0.075, 0.070, 0.040, 0.026, 0.047, 0.042]
ff_m_ece_stds_a0 = [0.005, 0.004, 0.002, 0.001, 0.005, 0.007]

ff_ece_means_a1 = [0.146, 0.165, 0.041, 0.069, 0.099, 0.092]
ff_ece_stds_a1 = [0.019, 0.021, 0.003, 0.005, 0.026, 0.024]
ff_m_ece_means_a1 = [0.066, 0.081, 0.016, 0.029, 0.046, 0.051]
ff_m_ece_stds_a1 = [0.004, 0.006, 0.002, 0.004, 0.007, 0.006]

ff_labels = ["age\n[gender]", "age\n[race]", "gender\n[age]", "gender\n[race]", "race\n[age]", "race\n[gender]"]

utk_ece_means_a0 = [0.200, 0.208, 0.086, 0.064, 0.127, 0.090]
utk_ece_stds_a0 = [0.011, 0.013, 0.003, 0.002, 0.028, 0.025]
utk_m_ece_means_a0 = [0.157, 0.149, 0.051, 0.038, 0.078, 0.088]
utk_m_ece_stds_a0 = [0.004, 0.005, 0.001, 0.002, 0.007, 0.006]

utk_ece_means_a1 = [0.164, 0.144, 0.042, 0.059, 0.147, 0.146]
utk_ece_stds_a1 = [0.013, 0.011, 0.002, 0.003, 0.018, 0.021]
utk_m_ece_means_a1 = [0.099, 0.089, 0.019, 0.032, 0.122, 0.115]
utk_m_ece_stds_a1 = [0.004, 0.003, 0.001, 0.001, 0.006, 0.006]

utk_labels = ["age\n[gender]", "age\n[race]", "gender\n[age]", "gender\n[race]", "race\n[age]", "race\n[gender]"]

# data taken from analyze_medical_image_calibration.ipynb

cx_ece_means_a0 = [0.011, 0.012, 0.013]
cx_ece_stds_a0 = [0.002, 0.002, 0.003]
cx_m_ece_means_a0 = [0.009, 0.009, 0.011]
cx_m_ece_stds_a0 = [0.001, 0.002, 0.002]

cx_ece_means_a1 = [0.020, 0.013, 0.012]
cx_ece_stds_a1 = [0.004, 0.003, 0.003]
cx_m_ece_means_a1 = [0.020, 0.012, 0.012]
cx_m_ece_stds_a1 = [0.001, 0.001, 0.002]

cx_labels = ["n.f.\n[age]", "n.f.\n[gender]", "n.f.\n[race]"]

# %%
plt.figure(figsize=(12, 3.1))

min_length = 0
plt.bar([x - 0.3 for x in range(min_length, len(ff_ece_means_a0))], 
        ff_ece_means_a0, yerr=ff_ece_stds_a0, color=c_member, label="Members", capsize=4, width=0.2, ecolor='C4')
plt.bar([x - 0.1 for x in range(min_length, len(ff_ece_means_a1))], 
        ff_ece_means_a1, yerr=ff_ece_stds_a1, color=c_member, capsize=4, width=0.2, ecolor='C2')
plt.bar([x + 0.1 for x in range(min_length, len(ff_m_ece_means_a0))], 
        ff_m_ece_means_a0, yerr=ff_m_ece_stds_a0, color=c_ens, label="Deep Ensemble", capsize=4, width=0.2, ecolor='C4')
plt.bar([x + 0.3 for x in range(min_length, len(ff_m_ece_means_a1))],
        ff_m_ece_means_a1, yerr=ff_m_ece_stds_a1, color=c_ens, capsize=4, width=0.2, ecolor='C2')
min_length = len(ff_ece_means_a0)
plt.bar([x - 0.3 for x in range(min_length, min_length + len(utk_ece_means_a0))],
        utk_ece_means_a0, yerr=utk_ece_stds_a0, color=c_member, capsize=4, width=0.2, ecolor='C4')
plt.bar([x - 0.1 for x in range(min_length, min_length + len(utk_ece_means_a1))],
        utk_ece_means_a1, yerr=utk_ece_stds_a1, color=c_member, capsize=4, width=0.2, ecolor='C2')
plt.bar([x + 0.1 for x in range(min_length, min_length + len(utk_m_ece_means_a0))],
        utk_m_ece_means_a0, yerr=utk_m_ece_stds_a0, color=c_ens, capsize=4, width=0.2, ecolor='C4')
plt.bar([x + 0.3 for x in range(min_length, min_length + len(utk_m_ece_means_a1))],
        utk_m_ece_means_a1, yerr=utk_m_ece_stds_a1, color=c_ens, capsize=4, width=0.2, ecolor='C2')
min_length += len(utk_ece_means_a0)
plt.bar([x - 0.3 for x in range(min_length, min_length + len(cx_ece_means_a0))],
        cx_ece_means_a0, yerr=cx_ece_stds_a0, color=c_member, capsize=4, width=0.2, ecolor='C4')
plt.bar([x - 0.1 for x in range(min_length, min_length + len(cx_ece_means_a1))],
        cx_ece_means_a1, yerr=cx_ece_stds_a1, color=c_member, capsize=4, width=0.2, ecolor='C2')
plt.bar([x + 0.1 for x in range(min_length, min_length + len(cx_m_ece_means_a0))],
        cx_m_ece_means_a0, yerr=cx_m_ece_stds_a0, color=c_ens, capsize=4, width=0.2, ecolor='C4')
plt.bar([x + 0.3 for x in range(min_length, min_length + len(cx_m_ece_means_a1))],
        cx_m_ece_means_a1, yerr=cx_m_ece_stds_a1, color=c_ens, capsize=4, width=0.2, ecolor='C2')
plt.xticks(range(len(ff_ece_means_a0) + len(utk_ece_means_a0) + len(cx_ece_means_a0)),
              ff_labels + utk_labels + cx_labels, rotation=0)
plt.text(2.5, 0.143, "FF", fontsize="medium", ha="center", bbox=dict(boxstyle='round, pad=0.3', edgecolor='black', facecolor='white', alpha=0.3))
plt.text(8.5, 0.143, "UTK", fontsize="medium", ha="center", bbox=dict(boxstyle='round, pad=0.3', edgecolor='black', facecolor='white', alpha=0.3))
plt.text(13, 0.143, "CX", fontsize="medium", ha="center", bbox=dict(boxstyle='round, pad=0.3', edgecolor='black', facecolor='white', alpha=0.3))
ymax = plt.gca().get_ylim()[1] * 1.05
plt.vlines(5.5, 0, ymax, color="black", linestyle=":", alpha=0.3)
plt.vlines(11.5, 0, ymax, color="black", linestyle=":", alpha=0.3)
plt.ylim(0, ymax)
plt.xlim(-0.55, 14.55)
plt.ylabel("ECE ($\\leftarrow$)")
plt.xlabel("Target\n[Protected Attribute]")
plt.bar(100, 0, yerr=0, color="C4", label="A=0")
plt.bar(100, 0, yerr=0, color="C2", label="A=1")
plt.legend(fontsize="x-small", ncol=2)
plt.tight_layout()
plt.savefig(os.path.join(PLOTS_PATH, "ece_per_a.pdf"))
plt.show()
